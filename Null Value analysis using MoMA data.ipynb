# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.set_option("display.max_columns", 30)

# %% [markdown]
# # Load MoMA data
# Using Museum of Modern Art data.
#
# Link to access data can be found [here](https://github.com/MuseumofModernArt/collection).

# %%
moma_df = pd.read_csv('Artworks.csv')

# %%
moma_df.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    ArtistBio Nationality BeginDate EndDate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# 4                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
#
#    Gender  Date                                             Medium  \
# 0  (Male)  1896      Ink and cut-and-pasted painted pages on paper
# 1  (Male)  1987                  Paint and colored pencil on print
# 2  (Male)  1903  Graphite, pen, color pencil, ink, and gouache ...
# 3  (Male)  1980  Photographic reproduction with colored synthet...
# 4  (Male)  1903  Graphite, color pencil, ink, and gouache on tr...
#
#                            Dimensions  \
# 0  19 1/8 x 66 1/2" (48.6 x 168.9 cm)
# 1       16 x 11 3/4" (40.6 x 29.8 cm)
# 2   13 1/2 x 12 1/2" (34.3 x 31.8 cm)
# 3           20 x 20" (50.8 x 50.8 cm)
# 4    15 1/8 x 7 1/2" (38.4 x 19.1 cm)
#
#                                           CreditLine AccessionNumber  \
# 0  Fractional and promised gift of Jo Carole and ...        885.1996
# 1  Gift of the architect in honor of Lily Auchinc...          1.1995
# 2             Gift of Jo Carole and Ronald S. Lauder          1.1997
# 3  Purchase and partial gift of the architect in ...          2.1995
# 4             Gift of Jo Carole and Ronald S. Lauder          2.1997
#
#   Classification             Department DateAcquired Cataloged  ObjectID  \
# 0   Architecture  Architecture & Design   1996-04-09         Y         2
# 1   Architecture  Architecture & Design   1995-01-17         Y         3
# 2   Architecture  Architecture & Design   1997-01-15         Y         4
# 3   Architecture  Architecture & Design   1995-01-17         Y         5
# 4   Architecture  Architecture & Design   1997-01-15         Y         6
#
#                                       URL  \
# 0  http://www.moma.org/collection/works/2
# 1  http://www.moma.org/collection/works/3
# 2  http://www.moma.org/collection/works/4
# 3  http://www.moma.org/collection/works/5
# 4  http://www.moma.org/collection/works/6
#
#                                         ThumbnailURL  Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                 NaN
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                 NaN
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...                 NaN
# 3  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...                 NaN
# 4  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...                 NaN
#
#    Depth (cm)  Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  \
# 0         NaN            NaN      48.6000          NaN          NaN
# 1         NaN            NaN      40.6401          NaN          NaN
# 2         NaN            NaN      34.3000          NaN          NaN
# 3         NaN            NaN      50.8000          NaN          NaN
# 4         NaN            NaN      38.4000          NaN          NaN
#
#    Width (cm)  Seat Height (cm)  Duration (sec.)
# 0    168.9000               NaN              NaN
# 1     29.8451               NaN              NaN
# 2     31.8000               NaN              NaN
# 3     50.8000               NaN              NaN
# 4     19.1000               NaN              NaN

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         136868 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             136868 non-null  object
#  7   Gender              136868 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
#  15  DateAcquired        131026 non-null  object
#  16  Cataloged           138151 non-null  object
#  17  ObjectID            138151 non-null  int64
#  18  URL                 87184 non-null   object
#  19  ThumbnailURL        76409 non-null   object
#  20  Circumference (cm)  10 non-null      float64
#  21  Depth (cm)          13839 non-null   float64
#  22  Diameter (cm)       1462 non-null    float64
#  23  Height (cm)         120355 non-null  float64
#  24  Length (cm)         742 non-null     float64
#  25  Weight (kg)         290 non-null     float64
#  26  Width (cm)          119434 non-null  float64
#  27  Seat Height (cm)    0 non-null       float64
#  28  Duration (sec.)     2140 non-null    float64
# dtypes: float64(9), int64(1), object(19)
# memory usage: 30.6+ MB

# %%
moma_df.replace('()', np.NaN, inplace= True)

# %%
moma_df.EndDate.replace('(0)', np.NaN, inplace= True)

# %%
moma_df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate  \
# 0                     (Austrian)             (1841)             (1918)
# 1                       (French)             (1944)                NaN
# 2                     (Austrian)             (1876)             (1957)
# 3                            NaN             (1944)                NaN
# 4                     (Austrian)             (1876)             (1957)
# ...                          ...                ...                ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)
# 138147                   (Swiss)             (1889)             (1943)
# 138148                   (Swiss)             (1889)             (1943)
# 138149                   (Swiss)             (1889)             (1943)
# 138150                   (Swiss)             (1889)             (1943)
#
#                   Gender     Date  \
# 0                 (Male)     1896
# 1                 (Male)     1987
# 2                 (Male)     1903
# 3                 (Male)     1980
# 4                 (Male)     1903
# ...                  ...      ...
# 138146  () (Male) (Male)  c. 1890
# 138147          (Female)     1939
# 138148          (Female)     1939
# 138149          (Female)     1939
# 138150          (Female)     1939
#
#                                                    Medium  \
# 0           Ink and cut-and-pasted painted pages on paper
# 1                       Paint and colored pencil on print
# 2       Graphite, pen, color pencil, ink, and gouache ...
# 3       Photographic reproduction with colored synthet...
# 4       Graphite, color pencil, ink, and gouache on tr...
# ...                                                   ...
# 138146                               Gelatin silver print
# 138147  One from an illustrated book with four line bl...
# 138148  One from an illustrated book with four line bl...
# 138149  One from an illustrated book with four line bl...
# 138150  One from an illustrated book with four line bl...
#
#                                                Dimensions  \
# 0                      19 1/8 x 66 1/2" (48.6 x 168.9 cm)
# 1                           16 x 11 3/4" (40.6 x 29.8 cm)
# 2                       13 1/2 x 12 1/2" (34.3 x 31.8 cm)
# 3                               20 x 20" (50.8 x 50.8 cm)
# 4                        15 1/8 x 7 1/2" (38.4 x 19.1 cm)
# ...                                                   ...
# 138146                    4 1/4 × 6 1/2" (10.8 × 16.5 cm)
# 138147  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
# 138148  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
# 138149  composition: 4 5/16 × 3 15/16" (11 × 10 cm); p...
# 138150  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
#
#                                                CreditLine AccessionNumber  \
# 0       Fractional and promised gift of Jo Carole and ...        885.1996
# 1       Gift of the architect in honor of Lily Auchinc...          1.1995
# 2                  Gift of Jo Carole and Ronald S. Lauder          1.1997
# 3       Purchase and partial gift of the architect in ...          2.1995
# 4                  Gift of Jo Carole and Ronald S. Lauder          2.1997
# ...                                                   ...             ...
# 138146                     Gift of John Jeremiah Sullivan      TR16527.25
# 138147  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.1
# 138148  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.2
# 138149  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.3
# 138150  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.4
#
#           Classification             Department DateAcquired Cataloged  \
# 0           Architecture  Architecture & Design   1996-04-09         Y
# 1           Architecture  Architecture & Design   1995-01-17         Y
# 2           Architecture  Architecture & Design   1997-01-15         Y
# 3           Architecture  Architecture & Design   1995-01-17         Y
# 4           Architecture  Architecture & Design   1997-01-15         Y
# ...                  ...                    ...          ...       ...
# 138146        Photograph            Photography   2020-10-07         Y
# 138147  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138148  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138149  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138150  Illustrated Book      Drawings & Prints   2019-12-11         Y
#
#         ObjectID                                          URL  \
# 0              2       http://www.moma.org/collection/works/2
# 1              3       http://www.moma.org/collection/works/3
# 2              4       http://www.moma.org/collection/works/4
# 3              5       http://www.moma.org/collection/works/5
# 4              6       http://www.moma.org/collection/works/6
# ...          ...                                          ...
# 138146    418928  http://www.moma.org/collection/works/418928
# 138147    419286  http://www.moma.org/collection/works/419286
# 138148    419287  http://www.moma.org/collection/works/419287
# 138149    419288  http://www.moma.org/collection/works/419288
# 138150    419289  http://www.moma.org/collection/works/419289
#
#                                              ThumbnailURL  Circumference (cm)  \
# 0       http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                 NaN
# 1       http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                 NaN
# 2       http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...                 NaN
# 3       http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...                 NaN
# 4       http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...                 NaN
# ...                                                   ...                 ...
# 138146  http://www.moma.org/media/W1siZiIsIjQ5MjcyMiJd...                 NaN
# 138147  http://www.moma.org/media/W1siZiIsIjQ4NTExNSJd...                 NaN
# 138148  http://www.moma.org/media/W1siZiIsIjQ4NTExOCJd...                 NaN
# 138149  http://www.moma.org/media/W1siZiIsIjQ4NTEyMCJd...                 NaN
# 138150  http://www.moma.org/media/W1siZiIsIjQ4NTEyMSJd...                 NaN
#
#         Depth (cm)  Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  \
# 0              NaN            NaN    48.600000          NaN          NaN
# 1              NaN            NaN    40.640100          NaN          NaN
# 2              NaN            NaN    34.300000          NaN          NaN
# 3              NaN            NaN    50.800000          NaN          NaN
# 4              NaN            NaN    38.400000          NaN          NaN
# ...            ...            ...          ...          ...          ...
# 138146         NaN            NaN    10.795022          NaN          NaN
# 138147         NaN            NaN    13.500000          NaN          NaN
# 138148         NaN            NaN    13.500000          NaN          NaN
# 138149         NaN            NaN    11.000000          NaN          NaN
# 138150         NaN            NaN    13.500000          NaN          NaN
#
#         Width (cm)  Seat Height (cm)  Duration (sec.)
# 0       168.900000               NaN              NaN
# 1        29.845100               NaN              NaN
# 2        31.800000               NaN              NaN
# 3        50.800000               NaN              NaN
# 4        19.100000               NaN              NaN
# ...            ...               ...              ...
# 138146   16.510033               NaN              NaN
# 138147   10.000000               NaN              NaN
# 138148   10.000000               NaN              NaN
# 138149   10.000000               NaN              NaN
# 138150   10.000000               NaN              NaN
#
# [138151 rows x 29 columns]

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         131843 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             90797 non-null   object
#  7   Gender              129510 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
#  15  DateAcquired        131026 non-null  object
#  16  Cataloged           138151 non-null  object
#  17  ObjectID            138151 non-null  int64
#  18  URL                 87184 non-null   object
#  19  ThumbnailURL        76409 non-null   object
#  20  Circumference (cm)  10 non-null      float64
#  21  Depth (cm)          13839 non-null   float64
#  22  Diameter (cm)       1462 non-null    float64
#  23  Height (cm)         120355 non-null  float64
#  24  Length (cm)         742 non-null     float64
#  25  Weight (kg)         290 non-null     float64
#  26  Width (cm)          119434 non-null  float64
#  27  Seat Height (cm)    0 non-null       float64
#  28  Duration (sec.)     2140 non-null    float64
# dtypes: float64(9), int64(1), object(19)
# memory usage: 30.6+ MB

# %%
moma_df.isna()
# Out:
#         Title  Artist  ConstituentID  ArtistBio  Nationality  BeginDate  \
# 0       False   False          False      False        False      False
# 1       False   False          False      False        False      False
# 2       False   False          False      False        False      False
# 3       False   False          False      False         True      False
# 4       False   False          False      False        False      False
# ...       ...     ...            ...        ...          ...        ...
# 138146  False   False          False      False        False      False
# 138147  False   False          False      False        False      False
# 138148  False   False          False      False        False      False
# 138149  False   False          False      False        False      False
# 138150  False   False          False      False        False      False
#
#         EndDate  Gender   Date  Medium  Dimensions  CreditLine  \
# 0         False   False  False   False       False       False
# 1          True   False  False   False       False       False
# 2         False   False  False   False       False       False
# 3          True   False  False   False       False       False
# 4         False   False  False   False       False       False
# ...         ...     ...    ...     ...         ...         ...
# 138146    False   False  False   False       False       False
# 138147    False   False  False   False       False       False
# 138148    False   False  False   False       False       False
# 138149    False   False  False   False       False       False
# 138150    False   False  False   False       False       False
#
#         AccessionNumber  Classification  Department  DateAcquired  Cataloged  \
# 0                 False           False       False         False      False
# 1                 False           False       False         False      False
# 2                 False           False       False         False      False
# 3                 False           False       False         False      False
# 4                 False           False       False         False      False
# ...                 ...             ...         ...           ...        ...
# 138146            False           False       False         False      False
# 138147            False           False       False         False      False
# 138148            False           False       False         False      False
# 138149            False           False       False         False      False
# 138150            False           False       False         False      False
#
#         ObjectID    URL  ThumbnailURL  Circumference (cm)  Depth (cm)  \
# 0          False  False         False                True        True
# 1          False  False         False                True        True
# 2          False  False         False                True        True
# 3          False  False         False                True        True
# 4          False  False         False                True        True
# ...          ...    ...           ...                 ...         ...
# 138146     False  False         False                True        True
# 138147     False  False         False                True        True
# 138148     False  False         False                True        True
# 138149     False  False         False                True        True
# 138150     False  False         False                True        True
#
#         Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  Width (cm)  \
# 0                True        False         True         True       False
# 1                True        False         True         True       False
# 2                True        False         True         True       False
# 3                True        False         True         True       False
# 4                True        False         True         True       False
# ...               ...          ...          ...          ...         ...
# 138146           True        False         True         True       False
# 138147           True        False         True         True       False
# 138148           True        False         True         True       False
# 138149           True        False         True         True       False
# 138150           True        False         True         True       False
#
#         Seat Height (cm)  Duration (sec.)
# 0                   True             True
# 1                   True             True
# 2                   True             True
# 3                   True             True
# 4                   True             True
# ...                  ...              ...
# 138146              True             True
# 138147              True             True
# 138148              True             True
# 138149              True             True
# 138150              True             True
#
# [138151 rows x 29 columns]

# %%
moma_df.isna().sum()
# Out:
# Title                     39
# Artist                  1283
# ConstituentID           1283
# ArtistBio               5925
# Nationality             6308
# BeginDate               1283
# EndDate                47354
# Gender                  8641
# Date                    2202
# Medium                  9701
# Dimensions              9754
# CreditLine              2437
# AccessionNumber            0
# Classification             0
# Department                 0
# DateAcquired            7125
# Cataloged                  0
# ObjectID                   0
# URL                    50967
# ThumbnailURL           61742
# Circumference (cm)    138141
# Depth (cm)            124312
# Diameter (cm)         136689
# Height (cm)            17796
# Length (cm)           137409
# Weight (kg)           137861
# Width (cm)             18717
# Seat Height (cm)      138151
# Duration (sec.)       136011
# dtype: int64

# %%
moma_df.notna().sum()
# Out:
# Title                 138112
# Artist                136868
# ConstituentID         136868
# ArtistBio             132226
# Nationality           131843
# BeginDate             136868
# EndDate                90797
# Gender                129510
# Date                  135949
# Medium                128450
# Dimensions            128397
# CreditLine            135714
# AccessionNumber       138151
# Classification        138151
# Department            138151
# DateAcquired          131026
# Cataloged             138151
# ObjectID              138151
# URL                    87184
# ThumbnailURL           76409
# Circumference (cm)        10
# Depth (cm)             13839
# Diameter (cm)           1462
# Height (cm)           120355
# Length (cm)              742
# Weight (kg)              290
# Width (cm)            119434
# Seat Height (cm)           0
# Duration (sec.)         2140
# dtype: int64

# %%
moma_df.drop(['Seat Height (cm)'], axis= 1, inplace= True)

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         131843 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             90797 non-null   object
#  7   Gender              129510 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
#  15  DateAcquired        131026 non-null  object
#  16  Cataloged           138151 non-null  object
#  17  ObjectID            138151 non-null  int64
#  18  URL                 87184 non-null   object
#  19  ThumbnailURL        76409 non-null   object
#  20  Circumference (cm)  10 non-null      float64
#  21  Depth (cm)          13839 non-null   float64
#  22  Diameter (cm)       1462 non-null    float64
#  23  Height (cm)         120355 non-null  float64
#  24  Length (cm)         742 non-null     float64
#  25  Weight (kg)         290 non-null     float64
#  26  Width (cm)          119434 non-null  float64
#  27  Duration (sec.)     2140 non-null    float64
# dtypes: float64(8), int64(1), object(19)
# memory usage: 29.5+ MB

# %%
# moma_df.fillna({'Depth': 0}, inplace= True)
moma_df['Depth (cm)'].fillna(value= 0, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# (Male)                                              104140
# (Female)                                             17821
# (Male) (Male)                                         1759
# (Male) (Male) (Male)                                   876
# (Male) ()                                              817
#                                                      ...
# (Male) (Male) () (Male) (Male) (Male) (Male)             1
# (Male) () (Male) (Male) (Male) (Male) ()                 1
# (Male) (Male) () (Female)                                1
# () (Male) () ()                                          1
# (Male) (Male) (Male) (Female) (Male) (Female) ()         1
# Name: Gender, Length: 408, dtype: int64

# %%
moma_df.Gender.nunique()
# Out:
# 408

# %%
moma_df.Gender.str.count('(Female)').sum()
# Out:
# 21417.0

# %%
moma_df.Gender.str.count('(Male)').sum()
# Out:
# 119598.0

# %%
moma_df.Gender.str.count('(Male)').sum() + moma_df.Gender.str.count('(Female)').sum()
# Out:
# 141015.0

# %%
moma_df.Gender = moma_df.Gender.astype(str).str.lower()
moma_df.replace({'Gender': {'nan' : 'U'}}, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# (male)                                                                                           104168
# (female)                                                                                          17823
# U                                                                                                  8641
# (male) (male)                                                                                      1760
# (male) (male) (male)                                                                                876
#                                                                                                   ...
# (male) (male) (male) (male) (male) (male) (male) (male) (male) (male) (male) (male) (male) ()         1
# (male) (male) (male) (male) (male) (male) (male) (male) (female) (female) ()                          1
# () (female) (female) (male) (male) (male) (male)                                                      1
# (male) (male) (male) (male) (female)                                                                  1
# () (male) (male) () (male) (male) (male) (male) (female) (female) (male) (male) (male) (male)         1
# Name: Gender, Length: 404, dtype: int64

# %%
# moma_df[moma_df['Gender'] == '(non-binary)']

# %%
male = 0
female = 0
for k,v in moma_df.Gender.iteritems():
    male = v.count('(male)')
    female = v.count('(female)')
    non_binary = v.count('(non-binary)')
    if male > female:
        moma_df.replace({'Gender': {v : 'M'}}, inplace= True)
    elif female > male:
        moma_df.replace({'Gender': {v : 'F'}}, inplace= True)
    elif non_binary > 0:
        moma_df.replace({'Gender': {v : 'NB'}}, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# M                                                                                                        109662
# F                                                                                                         18173
# U                                                                                                          8641
# (male) (female)                                                                                             714
# (female) (male)                                                                                             484
# () ()                                                                                                       147
# () (male) (female)                                                                                          107
# (male) (female) ()                                                                                           56
# () () ()                                                                                                     26
# (male) (male) (female) (female)                                                                              25
# () (female) (male)                                                                                           23
# () (male) (female) ()                                                                                        17
# (female) (male) ()                                                                                           13
# NB                                                                                                           12
# (male) () (female)                                                                                           10
# (female) (male) (male) (female) () ()                                                                         5
# (male) (female) (male) (female)                                                                               4
# () () () () ()                                                                                                3
# () (female) (male) ()                                                                                         3
# (female) () (male)                                                                                            2
# () (female) (male) (male) (female)                                                                            2
# (male) (female) (female) (male) ()                                                                            2
# () () () ()                                                                                                   2
# () (female) (female) (male) (male)                                                                            1
# (female) (male) (female) (male) ()                                                                            1
# (male) (female) (female) (male)                                                                               1
# (female) (female) (male) (male) ()                                                                            1
# () (female) (male) (male) (female) (female) (male)                                                            1
# () (female) (male) (female) (male) (female) (male)                                                            1
# () (female) (female) (female) (male) (male) (male) (female) (female) () (male) (male) (female) (male)         1
# (female) (male) (male) (female) ()                                                                            1
# () (male) (male) (female) (female)                                                                            1
# (male) (male) (female) (female) (female) (male)                                                               1
# (female) () (male) (female) (male) (female) (male)                                                            1
# () () () () () ()                                                                                             1
# (male) (female) (male) (female) ()                                                                            1
# (female) () (male) ()                                                                                         1
# () (male) (female) (female) (male)                                                                            1
# (male) (female) () ()                                                                                         1
# (female) (male) () ()                                                                                         1
# () () () (male) () (female)                                                                                   1
# Name: Gender, dtype: int64

# %%
#separating this step from the other saves on execution time
male = 0
female = 0
unknown = 0
nonbinary = 0

for k,v in moma_df.Gender.iteritems():
    male = v.count('(male)') + v.count('M')
    female = v.count('(female)') + v.count('F')
    unknown = v.count('U')
    nonbinary = v.count('NB')
    if unknown < 1 and nonbinary < 1 and male == female:
        moma_df.replace({'Gender': {v : 'U'}}, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# M     109662
# F      18173
# U      10304
# NB        12
# Name: Gender, dtype: int64

# %%
moma_df.URL.isna().sum()
# Out:
# 50967

# %%
moma_df['URL'].fillna(value= 'none_listed', inplace= True)

# %%
moma_df.URL.isna().sum()
# Out:
# 0

# %%
moma_df.BeginDate.isna().sum()
# Out:
# 1283

# %%
moma_df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality          BeginDate            EndDate Gender  \
# 0                     (Austrian)             (1841)             (1918)      M
# 1                       (French)             (1944)                NaN      M
# 2                     (Austrian)             (1876)             (1957)      M
# 3                            NaN             (1944)                NaN      M
# 4                     (Austrian)             (1876)             (1957)      M
# ...                          ...                ...                ...    ...
# 138146  () (American) (American)  (0) (1861) (1860)  (0) (1934) (1933)      M
# 138147                   (Swiss)             (1889)             (1943)      F
# 138148                   (Swiss)             (1889)             (1943)      F
# 138149                   (Swiss)             (1889)             (1943)      F
# 138150                   (Swiss)             (1889)             (1943)      F
#
#            Date                                             Medium  \
# 0          1896      Ink and cut-and-pasted painted pages on paper
# 1          1987                  Paint and colored pencil on print
# 2          1903  Graphite, pen, color pencil, ink, and gouache ...
# 3          1980  Photographic reproduction with colored synthet...
# 4          1903  Graphite, color pencil, ink, and gouache on tr...
# ...         ...                                                ...
# 138146  c. 1890                               Gelatin silver print
# 138147     1939  One from an illustrated book with four line bl...
# 138148     1939  One from an illustrated book with four line bl...
# 138149     1939  One from an illustrated book with four line bl...
# 138150     1939  One from an illustrated book with four line bl...
#
#                                                Dimensions  \
# 0                      19 1/8 x 66 1/2" (48.6 x 168.9 cm)
# 1                           16 x 11 3/4" (40.6 x 29.8 cm)
# 2                       13 1/2 x 12 1/2" (34.3 x 31.8 cm)
# 3                               20 x 20" (50.8 x 50.8 cm)
# 4                        15 1/8 x 7 1/2" (38.4 x 19.1 cm)
# ...                                                   ...
# 138146                    4 1/4 × 6 1/2" (10.8 × 16.5 cm)
# 138147  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
# 138148  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
# 138149  composition: 4 5/16 × 3 15/16" (11 × 10 cm); p...
# 138150  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
#
#                                                CreditLine AccessionNumber  \
# 0       Fractional and promised gift of Jo Carole and ...        885.1996
# 1       Gift of the architect in honor of Lily Auchinc...          1.1995
# 2                  Gift of Jo Carole and Ronald S. Lauder          1.1997
# 3       Purchase and partial gift of the architect in ...          2.1995
# 4                  Gift of Jo Carole and Ronald S. Lauder          2.1997
# ...                                                   ...             ...
# 138146                     Gift of John Jeremiah Sullivan      TR16527.25
# 138147  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.1
# 138148  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.2
# 138149  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.3
# 138150  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.4
#
#           Classification             Department DateAcquired Cataloged  \
# 0           Architecture  Architecture & Design   1996-04-09         Y
# 1           Architecture  Architecture & Design   1995-01-17         Y
# 2           Architecture  Architecture & Design   1997-01-15         Y
# 3           Architecture  Architecture & Design   1995-01-17         Y
# 4           Architecture  Architecture & Design   1997-01-15         Y
# ...                  ...                    ...          ...       ...
# 138146        Photograph            Photography   2020-10-07         Y
# 138147  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138148  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138149  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138150  Illustrated Book      Drawings & Prints   2019-12-11         Y
#
#         ObjectID                                          URL  \
# 0              2       http://www.moma.org/collection/works/2
# 1              3       http://www.moma.org/collection/works/3
# 2              4       http://www.moma.org/collection/works/4
# 3              5       http://www.moma.org/collection/works/5
# 4              6       http://www.moma.org/collection/works/6
# ...          ...                                          ...
# 138146    418928  http://www.moma.org/collection/works/418928
# 138147    419286  http://www.moma.org/collection/works/419286
# 138148    419287  http://www.moma.org/collection/works/419287
# 138149    419288  http://www.moma.org/collection/works/419288
# 138150    419289  http://www.moma.org/collection/works/419289
#
#                                              ThumbnailURL  Circumference (cm)  \
# 0       http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                 NaN
# 1       http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                 NaN
# 2       http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...                 NaN
# 3       http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...                 NaN
# 4       http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...                 NaN
# ...                                                   ...                 ...
# 138146  http://www.moma.org/media/W1siZiIsIjQ5MjcyMiJd...                 NaN
# 138147  http://www.moma.org/media/W1siZiIsIjQ4NTExNSJd...                 NaN
# 138148  http://www.moma.org/media/W1siZiIsIjQ4NTExOCJd...                 NaN
# 138149  http://www.moma.org/media/W1siZiIsIjQ4NTEyMCJd...                 NaN
# 138150  http://www.moma.org/media/W1siZiIsIjQ4NTEyMSJd...                 NaN
#
#         Depth (cm)  Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  \
# 0              0.0            NaN    48.600000          NaN          NaN
# 1              0.0            NaN    40.640100          NaN          NaN
# 2              0.0            NaN    34.300000          NaN          NaN
# 3              0.0            NaN    50.800000          NaN          NaN
# 4              0.0            NaN    38.400000          NaN          NaN
# ...            ...            ...          ...          ...          ...
# 138146         0.0            NaN    10.795022          NaN          NaN
# 138147         0.0            NaN    13.500000          NaN          NaN
# 138148         0.0            NaN    13.500000          NaN          NaN
# 138149         0.0            NaN    11.000000          NaN          NaN
# 138150         0.0            NaN    13.500000          NaN          NaN
#
#         Width (cm)  Duration (sec.)
# 0       168.900000              NaN
# 1        29.845100              NaN
# 2        31.800000              NaN
# 3        50.800000              NaN
# 4        19.100000              NaN
# ...            ...              ...
# 138146   16.510033              NaN
# 138147   10.000000              NaN
# 138148   10.000000              NaN
# 138149   10.000000              NaN
# 138150   10.000000              NaN
#
# [138151 rows x 28 columns]

# %%
# remove all () from BeginDate column
import re
moma_df['BeginDate'] = moma_df['BeginDate'].str.replace(r'[()]', '', regex= True)

# %%
# moma_df['BeginDate'] = moma_df['BeginDate'].str.replace('0', '', regex= False)

# %%
moma_df['Date'] = moma_df['Date'].str.replace('c.', '', regex= True)
moma_df['Date'] = moma_df['Date'].str.replace('s', '', regex= True)

# %%
# check for entries with more than 4 characters
moma_df['DateCount'] = moma_df['Date'].str.len()

# %%
# keep first 4 characters (date) if date is a range 
# EX: 1974-75 or 1988-1989
moma_df.loc[moma_df.DateCount == 7, 'Date'] = moma_df['Date'].str[:4]

# %%
moma_df.loc[moma_df.DateCount == 9, 'Date'] = moma_df['Date'].str[:4]

# %%
# create count for number of characters in date string
moma_df['DateCount'] = moma_df['Date'].str.len()
moma_df[moma_df['DateCount'] > 4]
# Out:
#                                                     Title  \
# 78      Villa Snellman, Djursholm, Sweden, Elevation o...
# 146                    Unidentified project (Perspective)
# 170     Chikatsu-Asuka Historical Museum, Minami-Kawac...
# 188     American System-Built Houses for The Richards ...
# 189     American System-Built Houses for The Richards ...
# ...                                                   ...
# 138142                                           Untitled
# 138143                                           Untitled
# 138144                                           Untitled
# 138145                                 Silver Springs, FL
# 138146                                           Untitled
#
#                                                    Artist  \
# 78                                    Erik Gunnar Asplund
# 146                                      Erich Mendelsohn
# 170                                            Tadao Ando
# 188                                    Frank Lloyd Wright
# 189                                    Frank Lloyd Wright
# ...                                                   ...
# 138142                               Unknown photographer
# 138143                               Unknown photographer
# 138144                               Unknown photographer
# 138145                               Unknown photographer
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
#
#                  ConstituentID  \
# 78                          27
# 146                       8219
# 170                       7055
# 188                       6459
# 189                       6459
# ...                        ...
# 138142                    8595
# 138143                    8595
# 138144                    8595
# 138145                    8595
# 138146  133005, 133006, 133007
#
#                                                ArtistBio  \
# 78                                  (Swedish, 1885–1940)
# 146     (American, born Germany (now Poland). 1887–1953)
# 170                                (Japanese, born 1941)
# 188                                (American, 1867–1959)
# 189                                (American, 1867–1959)
# ...                                                  ...
# 138142                                               NaN
# 138143                                               NaN
# 138144                                               NaN
# 138145                                               NaN
# 138146       (American, 1861–1934) (American, 1860–1933)
#
#                      Nationality    BeginDate            EndDate Gender  \
# 78                     (Swedish)         1885             (1940)      M
# 146                   (American)         1887             (1953)      M
# 170                   (Japanese)         1941                NaN      M
# 188                   (American)         1867             (1959)      M
# 189                   (American)         1867             (1959)      M
# ...                          ...          ...                ...    ...
# 138142                       NaN            0                NaN      U
# 138143                       NaN            0                NaN      U
# 138144                       NaN            0                NaN      U
# 138145                       NaN            0                NaN      U
# 138146  () (American) (American)  0 1861 1860  (0) (1934) (1933)      M
#
#                  Date                                             Medium  \
# 78               1917  Graphite and crayon on tracing paper mounted o...
# 146              1935                                              Print
# 170           1989-91          Graphite and crayon with scoring on paper
# 188           1915-17                                         Lithograph
# 189           1915-17                                         Lithograph
# ...               ...                                                ...
# 138142           1910                Gelatin silver print, printed later
# 138143        1918-30                    Gelatin silver print (postcard)
# 138144           1900                               Gelatin silver print
# 138145  February 1903                               Gelatin silver print
# 138146           1890                               Gelatin silver print
#
#                                 Dimensions  \
# 78        9 1/8 x 13 3/4" (23.2 x 34.9 cm)
# 146      15 3/4 x 18 15/16" (40 x 48.1 cm)
# 170      11 5/8 x 33 1/8" (29.5 x 84.1 cm)
# 188       8 1/2 x 11 1/8" (21.6 x 28.3 cm)
# 189           8 5/8 x 11" (21.9 x 27.9 cm)
# ...                                    ...
# 138142  8 1/16 × 13 1/16" (20.5 × 33.2 cm)
# 138143          4 × 3 3/8" (10.2 × 8.6 cm)
# 138144    6 7/16 × 9 3/4" (16.4 × 24.7 cm)
# 138145    3 7/16 × 11 13/16" (8.8 × 30 cm)
# 138146     4 1/4 × 6 1/2" (10.8 × 16.5 cm)
#
#                                                CreditLine AccessionNumber  \
# 78      Gift of Mr. and Mrs. Edward Larrabee Barnes, R...         33.1990
# 146                           Gift of Milton Scheingarten        100.2000
# 170                                 Gift of the architect        140.1993
# 188     Gift of David Rockefeller, Jr. Fund, Ira Howar...     155.1993.15
# 189     Gift of David Rockefeller, Jr. Fund, Ira Howar...     155.1993.16
# ...                                                   ...             ...
# 138142                     Gift of John Jeremiah Sullivan      TR16527.21
# 138143                     Gift of John Jeremiah Sullivan      TR16527.22
# 138144                     Gift of John Jeremiah Sullivan      TR16527.23
# 138145                     Gift of John Jeremiah Sullivan      TR16527.24
# 138146                     Gift of John Jeremiah Sullivan      TR16527.25
#
#        Classification             Department DateAcquired Cataloged  ObjectID  \
# 78       Architecture  Architecture & Design   1990-01-17         Y       107
# 146      Architecture  Architecture & Design   2000-01-19         Y       195
# 170      Architecture  Architecture & Design   1993-05-04         Y       224
# 188      Architecture  Architecture & Design   1993-05-04         Y       244
# 189      Architecture  Architecture & Design   1993-05-04         Y       245
# ...               ...                    ...          ...       ...       ...
# 138142     Photograph            Photography   2020-10-07         Y    418745
# 138143     Photograph            Photography   2020-10-07         Y    418746
# 138144     Photograph            Photography   2020-10-07         Y    418747
# 138145     Photograph            Photography   2020-10-07         Y    418748
# 138146     Photograph            Photography   2020-10-07         Y    418928
#
#                                                 URL  \
# 78         http://www.moma.org/collection/works/107
# 146        http://www.moma.org/collection/works/195
# 170        http://www.moma.org/collection/works/224
# 188        http://www.moma.org/collection/works/244
# 189        http://www.moma.org/collection/works/245
# ...                                             ...
# 138142  http://www.moma.org/collection/works/418745
# 138143  http://www.moma.org/collection/works/418746
# 138144  http://www.moma.org/collection/works/418747
# 138145  http://www.moma.org/collection/works/418748
# 138146  http://www.moma.org/collection/works/418928
#
#                                              ThumbnailURL  Circumference (cm)  \
# 78      http://www.moma.org/media/W1siZiIsIjc3OSJdLFsi...                 NaN
# 146                                                   NaN                 NaN
# 170     http://www.moma.org/media/W1siZiIsIjI0MjEiXSxb...                 NaN
# 188     http://www.moma.org/media/W1siZiIsIjI2NDciXSxb...                 NaN
# 189     http://www.moma.org/media/W1siZiIsIjI2NDgiXSxb...                 NaN
# ...                                                   ...                 ...
# 138142  http://www.moma.org/media/W1siZiIsIjQ5MjcxNCJd...                 NaN
# 138143  http://www.moma.org/media/W1siZiIsIjQ5MjcxNiJd...                 NaN
# 138144  http://www.moma.org/media/W1siZiIsIjQ5MjcxOCJd...                 NaN
# 138145  http://www.moma.org/media/W1siZiIsIjQ5MjcyMCJd...                 NaN
# 138146  http://www.moma.org/media/W1siZiIsIjQ5MjcyMiJd...                 NaN
#
#         Depth (cm)  Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  \
# 78             0.0            NaN    23.200000          NaN          NaN
# 146            0.0            NaN    21.000000          NaN          NaN
# 170            0.0            NaN    29.500000          NaN          NaN
# 188            0.0            NaN    21.600000          NaN          NaN
# 189            0.0            NaN    21.900000          NaN          NaN
# ...            ...            ...          ...          ...          ...
# 138142         0.0            NaN    20.500000          NaN          NaN
# 138143         0.0            NaN    10.200000          NaN          NaN
# 138144         0.0            NaN    16.360000          NaN          NaN
# 138145         0.0            NaN     8.800000          NaN          NaN
# 138146         0.0            NaN    10.795022          NaN          NaN
#
#         Width (cm)  Duration (sec.)  DateCount
# 78       34.900000              NaN        5.0
# 146      25.200000              NaN        5.0
# 170      84.100000              NaN        8.0
# 188      28.300000              NaN        8.0
# 189      27.900000              NaN        8.0
# ...            ...              ...        ...
# 138142   33.200000              NaN        5.0
# 138143    8.600000              NaN        8.0
# 138144   24.700000              NaN        5.0
# 138145   30.000000              NaN       13.0
# 138146   16.510033              NaN        5.0
#
# [25185 rows x 29 columns]

# %%
# moma_df[moma_df['DateCount'] > 4]

# %%
# remove any letters or characters
moma_df['Date'] = moma_df['Date'].str.replace(r'\D', '', regex= True)

# %%
moma_df['DateCount'] = moma_df['Date'].str.len()
moma_df[moma_df['DateCount'] > 4]
# Out:
#                                                     Title  \
# 170     Chikatsu-Asuka Historical Museum, Minami-Kawac...
# 188     American System-Built Houses for The Richards ...
# 189     American System-Built Houses for The Richards ...
# 190     American System-Built Houses for The Richards ...
# 193     American System-Built Houses for The Richards ...
# ...                                                   ...
# 138121  Title page (folio 2) from Mörder, Hoffnung der...
# 138131                                           Untitled
# 138132                                           Untitled
# 138134                                           Untitled
# 138143                                           Untitled
#
#                       Artist ConstituentID              ArtistBio Nationality  \
# 170               Tadao Ando          7055  (Japanese, born 1941)  (Japanese)
# 188       Frank Lloyd Wright          6459  (American, 1867–1959)  (American)
# 189       Frank Lloyd Wright          6459  (American, 1867–1959)  (American)
# 190       Frank Lloyd Wright          6459  (American, 1867–1959)  (American)
# 193       Frank Lloyd Wright          6459  (American, 1867–1959)  (American)
# ...                      ...           ...                    ...         ...
# 138121       Oskar Kokoschka          3197  (Austrian, 1886–1980)  (Austrian)
# 138131  Unknown photographer          8595                    NaN         NaN
# 138132  Unknown photographer          8595                    NaN         NaN
# 138134  Unknown photographer          8595                    NaN         NaN
# 138143  Unknown photographer          8595                    NaN         NaN
#
#        BeginDate EndDate Gender      Date  \
# 170         1941     NaN      M    198991
# 188         1867  (1959)      M    191517
# 189         1867  (1959)      M    191517
# 190         1867  (1959)      M    191517
# 193         1867  (1959)      M    191517
# ...          ...     ...    ...       ...
# 138121      1886  (1980)      M  19161910
# 138131         0     NaN      U    190710
# 138132         0     NaN      U    193040
# 138134         0     NaN      U    190720
# 138143         0     NaN      U    191830
#
#                                                    Medium  \
# 170             Graphite and crayon with scoring on paper
# 188                                            Lithograph
# 189                                            Lithograph
# 190                                            Lithograph
# 193                                            Lithograph
# ...                                                   ...
# 138121  Line block reproduction from an illustrated bo...
# 138131                    Gelatin silver print (postcard)
# 138132                               Gelatin silver print
# 138134                    Gelatin silver print (postcard)
# 138143                    Gelatin silver print (postcard)
#
#                                                Dimensions  \
# 170                     11 5/8 x 33 1/8" (29.5 x 84.1 cm)
# 188                      8 1/2 x 11 1/8" (21.6 x 28.3 cm)
# 189                          8 5/8 x 11" (21.9 x 27.9 cm)
# 190                          11 x 8 1/2" (27.9 x 21.6 cm)
# 193                          11 x 8 1/2" (27.9 x 21.6 cm)
# ...                                                   ...
# 138121  composition (irreg.): 4 1/8 × 3 1/8" (10.5 × 8...
# 138131                     3 1/4 × 5 3/8" (8.2 × 13.7 cm)
# 138132                      4 5/16 × 2 3/8" (10.9 × 6 cm)
# 138134                  3 1/16 × 4 13/16" (7.8 × 12.2 cm)
# 138143                         4 × 3 3/8" (10.2 × 8.6 cm)
#
#                                                CreditLine AccessionNumber  \
# 170                                 Gift of the architect        140.1993
# 188     Gift of David Rockefeller, Jr. Fund, Ira Howar...     155.1993.15
# 189     Gift of David Rockefeller, Jr. Fund, Ira Howar...     155.1993.16
# 190     Gift of David Rockefeller, Jr. Fund, Ira Howar...     155.1993.17
# 193     Gift of David Rockefeller, Jr. Fund, Ira Howar...      155.1993.4
# ...                                                   ...             ...
# 138121                Transferred from the Museum Library      580.1949.1
# 138131                     Gift of John Jeremiah Sullivan      TR16527.10
# 138132                     Gift of John Jeremiah Sullivan      TR16527.11
# 138134                     Gift of John Jeremiah Sullivan      TR16527.13
# 138143                     Gift of John Jeremiah Sullivan      TR16527.22
#
#           Classification             Department DateAcquired Cataloged  \
# 170         Architecture  Architecture & Design   1993-05-04         Y
# 188         Architecture  Architecture & Design   1993-05-04         Y
# 189         Architecture  Architecture & Design   1993-05-04         Y
# 190         Architecture  Architecture & Design   1993-05-04         Y
# 193         Architecture  Architecture & Design   1993-05-04         Y
# ...                  ...                    ...          ...       ...
# 138121  Illustrated Book      Drawings & Prints   1949-09-29         Y
# 138131        Photograph            Photography   2020-10-07         Y
# 138132        Photograph            Photography   2020-10-07         Y
# 138134        Photograph            Photography   2020-10-07         Y
# 138143        Photograph            Photography   2020-10-07         Y
#
#         ObjectID                                          URL  \
# 170          224     http://www.moma.org/collection/works/224
# 188          244     http://www.moma.org/collection/works/244
# 189          245     http://www.moma.org/collection/works/245
# 190          246     http://www.moma.org/collection/works/246
# 193          249     http://www.moma.org/collection/works/249
# ...          ...                                          ...
# 138121    418509  http://www.moma.org/collection/works/418509
# 138131    418734  http://www.moma.org/collection/works/418734
# 138132    418735  http://www.moma.org/collection/works/418735
# 138134    418737  http://www.moma.org/collection/works/418737
# 138143    418746  http://www.moma.org/collection/works/418746
#
#                                              ThumbnailURL  Circumference (cm)  \
# 170     http://www.moma.org/media/W1siZiIsIjI0MjEiXSxb...                 NaN
# 188     http://www.moma.org/media/W1siZiIsIjI2NDciXSxb...                 NaN
# 189     http://www.moma.org/media/W1siZiIsIjI2NDgiXSxb...                 NaN
# 190     http://www.moma.org/media/W1siZiIsIjI2NDkiXSxb...                 NaN
# 193     http://www.moma.org/media/W1siZiIsIjI2NTIiXSxb...                 NaN
# ...                                                   ...                 ...
# 138121  http://www.moma.org/media/W1siZiIsIjEyNjQ0NiJd...                 NaN
# 138131  http://www.moma.org/media/W1siZiIsIjQ5MjY5OSJd...                 NaN
# 138132  http://www.moma.org/media/W1siZiIsIjQ5MjcwMSJd...                 NaN
# 138134  http://www.moma.org/media/W1siZiIsIjQ5MjcwMyJd...                 NaN
# 138143  http://www.moma.org/media/W1siZiIsIjQ5MjcxNiJd...                 NaN
#
#         Depth (cm)  Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  \
# 170            0.0            NaN         29.5          NaN          NaN
# 188            0.0            NaN         21.6          NaN          NaN
# 189            0.0            NaN         21.9          NaN          NaN
# 190            0.0            NaN         27.9          NaN          NaN
# 193            0.0            NaN         27.9          NaN          NaN
# ...            ...            ...          ...          ...          ...
# 138121         0.0            NaN         10.5          NaN          NaN
# 138131         0.0            NaN          8.2          NaN          NaN
# 138132         0.0            NaN         10.9          NaN          NaN
# 138134         0.0            NaN          7.8          NaN          NaN
# 138143         0.0            NaN         10.2          NaN          NaN
#
#         Width (cm)  Duration (sec.)  DateCount
# 170           84.1              NaN        6.0
# 188           28.3              NaN        6.0
# 189           27.9              NaN        6.0
# 190           21.6              NaN        6.0
# 193           21.6              NaN        6.0
# ...            ...              ...        ...
# 138121         8.0              NaN        8.0
# 138131        13.7              NaN        6.0
# 138132         6.0              NaN        6.0
# 138134        12.2              NaN        6.0
# 138143         8.6              NaN        6.0
#
# [11930 rows x 29 columns]

# %%
moma_df.loc[moma_df.DateCount == 6, 'Date'] = moma_df['Date'].str[:4]

# %%
moma_df.loc[moma_df.DateCount == 8, 'Date'] = moma_df['Date'].str[:4]

# %%
moma_df['DateCount'] = moma_df['Date'].str.len()
# moma_df[moma_df['DateCount'] > 4]

# %%
# reviewing the dates, some of the later dates listed are after the artist has passed away
# chose to pick the first year (usually the first 4 digits)
moma_df.loc[moma_df.DateCount > 4, 'Date'] = moma_df['Date'].str[-4:]

# %%
moma_df['DateCount'] = moma_df['Date'].str.len()
moma_df[moma_df['DateCount'] > 4]
# Out:
# Empty DataFrame
# Columns: [Title, Artist, ConstituentID, ArtistBio, Nationality, BeginDate, EndDate, Gender, Date, Medium, Dimensions, CreditLine, AccessionNumber, Classification, Department, DateAcquired, Cataloged, ObjectID, URL, ThumbnailURL, Circumference (cm), Depth (cm), Diameter (cm), Height (cm), Length (cm), Weight (kg), Width (cm), Duration (sec.), DateCount]
# Index: []

# %%
moma_df['Date'] = moma_df['Date'].str.replace(' ', '')
# 
moma_df['Date'] = pd.to_numeric(moma_df['Date'])

# %%
# fill odd values with 0
moma_df.loc[moma_df['Date'] > 2020, 'Date'] = np.nan
moma_df.loc[moma_df['Date'] < 1500, 'Date'] = np.nan

# %%
moma_df.Date.isna().sum()
# Out:
# 6584

# %%
moma_df.Date.mean()
# Out:
# 1953.9855434873487

# %%
moma_df.Date.median()
# Out:
# 1962.0

# %% [markdown]
# Median and mean are fairly close. Let's use the median because mean may be lower because there may be outliers since we included years 1500 and above.

# %%
moma_df['Date'] = moma_df['Date'].fillna(moma_df.Date.median(), inplace= True)

# %%
moma_df.Date.isna().sum()
# Out:
# 138151

# %%
moma_df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                              Emil Hoppe
# ...                                                   ...
# 138146  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 138147                                 Sophie Taeuber-Arp
# 138148                                 Sophie Taeuber-Arp
# 138149                                 Sophie Taeuber-Arp
# 138150                                 Sophie Taeuber-Arp
#
#                  ConstituentID                                    ArtistBio  \
# 0                         6210                        (Austrian, 1841–1918)
# 1                         7470                          (French, born 1944)
# 2                         7605                        (Austrian, 1876–1957)
# 3                         7056    (French and Swiss, born Switzerland 1944)
# 4                         7605                        (Austrian, 1876–1957)
# ...                        ...                                          ...
# 138146  133005, 133006, 133007  (American, 1861–1934) (American, 1860–1933)
# 138147                    5777                           (Swiss, 1889–1943)
# 138148                    5777                           (Swiss, 1889–1943)
# 138149                    5777                           (Swiss, 1889–1943)
# 138150                    5777                           (Swiss, 1889–1943)
#
#                      Nationality    BeginDate            EndDate Gender  Date  \
# 0                     (Austrian)         1841             (1918)      M  None
# 1                       (French)         1944                NaN      M  None
# 2                     (Austrian)         1876             (1957)      M  None
# 3                            NaN         1944                NaN      M  None
# 4                     (Austrian)         1876             (1957)      M  None
# ...                          ...          ...                ...    ...   ...
# 138146  () (American) (American)  0 1861 1860  (0) (1934) (1933)      M  None
# 138147                   (Swiss)         1889             (1943)      F  None
# 138148                   (Swiss)         1889             (1943)      F  None
# 138149                   (Swiss)         1889             (1943)      F  None
# 138150                   (Swiss)         1889             (1943)      F  None
#
#                                                    Medium  \
# 0           Ink and cut-and-pasted painted pages on paper
# 1                       Paint and colored pencil on print
# 2       Graphite, pen, color pencil, ink, and gouache ...
# 3       Photographic reproduction with colored synthet...
# 4       Graphite, color pencil, ink, and gouache on tr...
# ...                                                   ...
# 138146                               Gelatin silver print
# 138147  One from an illustrated book with four line bl...
# 138148  One from an illustrated book with four line bl...
# 138149  One from an illustrated book with four line bl...
# 138150  One from an illustrated book with four line bl...
#
#                                                Dimensions  \
# 0                      19 1/8 x 66 1/2" (48.6 x 168.9 cm)
# 1                           16 x 11 3/4" (40.6 x 29.8 cm)
# 2                       13 1/2 x 12 1/2" (34.3 x 31.8 cm)
# 3                               20 x 20" (50.8 x 50.8 cm)
# 4                        15 1/8 x 7 1/2" (38.4 x 19.1 cm)
# ...                                                   ...
# 138146                    4 1/4 × 6 1/2" (10.8 × 16.5 cm)
# 138147  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
# 138148  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
# 138149  composition: 4 5/16 × 3 15/16" (11 × 10 cm); p...
# 138150  composition: 5 5/16 × 3 15/16" (13.5 × 10 cm);...
#
#                                                CreditLine AccessionNumber  \
# 0       Fractional and promised gift of Jo Carole and ...        885.1996
# 1       Gift of the architect in honor of Lily Auchinc...          1.1995
# 2                  Gift of Jo Carole and Ronald S. Lauder          1.1997
# 3       Purchase and partial gift of the architect in ...          2.1995
# 4                  Gift of Jo Carole and Ronald S. Lauder          2.1997
# ...                                                   ...             ...
# 138146                     Gift of John Jeremiah Sullivan      TR16527.25
# 138147  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.1
# 138148  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.2
# 138149  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.3
# 138150  The Abby Aldrich Rockefeller Endowment for Prints      762.2019.4
#
#           Classification             Department DateAcquired Cataloged  \
# 0           Architecture  Architecture & Design   1996-04-09         Y
# 1           Architecture  Architecture & Design   1995-01-17         Y
# 2           Architecture  Architecture & Design   1997-01-15         Y
# 3           Architecture  Architecture & Design   1995-01-17         Y
# 4           Architecture  Architecture & Design   1997-01-15         Y
# ...                  ...                    ...          ...       ...
# 138146        Photograph            Photography   2020-10-07         Y
# 138147  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138148  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138149  Illustrated Book      Drawings & Prints   2019-12-11         Y
# 138150  Illustrated Book      Drawings & Prints   2019-12-11         Y
#
#         ObjectID                                          URL  \
# 0              2       http://www.moma.org/collection/works/2
# 1              3       http://www.moma.org/collection/works/3
# 2              4       http://www.moma.org/collection/works/4
# 3              5       http://www.moma.org/collection/works/5
# 4              6       http://www.moma.org/collection/works/6
# ...          ...                                          ...
# 138146    418928  http://www.moma.org/collection/works/418928
# 138147    419286  http://www.moma.org/collection/works/419286
# 138148    419287  http://www.moma.org/collection/works/419287
# 138149    419288  http://www.moma.org/collection/works/419288
# 138150    419289  http://www.moma.org/collection/works/419289
#
#                                              ThumbnailURL  Circumference (cm)  \
# 0       http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...                 NaN
# 1       http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...                 NaN
# 2       http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...                 NaN
# 3       http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...                 NaN
# 4       http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...                 NaN
# ...                                                   ...                 ...
# 138146  http://www.moma.org/media/W1siZiIsIjQ5MjcyMiJd...                 NaN
# 138147  http://www.moma.org/media/W1siZiIsIjQ4NTExNSJd...                 NaN
# 138148  http://www.moma.org/media/W1siZiIsIjQ4NTExOCJd...                 NaN
# 138149  http://www.moma.org/media/W1siZiIsIjQ4NTEyMCJd...                 NaN
# 138150  http://www.moma.org/media/W1siZiIsIjQ4NTEyMSJd...                 NaN
#
#         Depth (cm)  Diameter (cm)  Height (cm)  Length (cm)  Weight (kg)  \
# 0              0.0            NaN    48.600000          NaN          NaN
# 1              0.0            NaN    40.640100          NaN          NaN
# 2              0.0            NaN    34.300000          NaN          NaN
# 3              0.0            NaN    50.800000          NaN          NaN
# 4              0.0            NaN    38.400000          NaN          NaN
# ...            ...            ...          ...          ...          ...
# 138146         0.0            NaN    10.795022          NaN          NaN
# 138147         0.0            NaN    13.500000          NaN          NaN
# 138148         0.0            NaN    13.500000          NaN          NaN
# 138149         0.0            NaN    11.000000          NaN          NaN
# 138150         0.0            NaN    13.500000          NaN          NaN
#
#         Width (cm)  Duration (sec.)  DateCount
# 0       168.900000              NaN        4.0
# 1        29.845100              NaN        4.0
# 2        31.800000              NaN        4.0
# 3        50.800000              NaN        4.0
# 4        19.100000              NaN        4.0
# ...            ...              ...        ...
# 138146   16.510033              NaN        4.0
# 138147   10.000000              NaN        4.0
# 138148   10.000000              NaN        4.0
# 138149   10.000000              NaN        4.0
# 138150   10.000000              NaN        4.0
#
# [138151 rows x 29 columns]

# %%
# import re

# for i in moma_df['BeginDate']:
#     pattern = r'[()]'
#     moma_df['BeginDate'] = re.sub(pattern, '', i)

# %%
#fill end date with average difference?
# moma_df['BeginEndDiff'] = moma_df['EndDate'] - moma_df['BeginDate']

# %%
# import re

# i = '(1889)'
# pattern = r'[()]'
# mod_string = re.sub(pattern, '', i)

# mod_string
