# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 30)

# %% [markdown]
# # Load MoMA data
# Using Museum of Modern Art data.
#
# Link to access data can be found [here](https://github.com/MuseumofModernArt/collection).

# %%
moma_df = pd.read_csv('Artworks.csv')

# %%
moma_df.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    ArtistBio Nationality BeginDate EndDate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# ...

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         136868 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             136868 non-null  object
#  7   Gender              136868 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
# ...

# %%
moma_df.replace('()', np.NaN, inplace= True)

# %%
moma_df.EndDate.replace('(0)', np.NaN, inplace= True)

# %%
moma_df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# ...                                                   ...
# 138146                                           Untitled
# 138147  Plate (folio 2 verso) from Muscheln und schirm...
# 138148  Plate (folio 6) from Muscheln und schirme (She...
# 138149  Plate (folio 12) from Muscheln und schirme (Sh...
# 138150  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                Christian de Portzamparc
# 2                                              Emil Hoppe
# ...

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 29 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         131843 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             90797 non-null   object
#  7   Gender              129510 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
# ...

# %%
moma_df.isna()
# Out:
#         Title  Artist  ConstituentID  ArtistBio  Nationality  BeginDate  \
# 0       False   False          False      False        False      False
# 1       False   False          False      False        False      False
# 2       False   False          False      False        False      False
# 3       False   False          False      False         True      False
# 4       False   False          False      False        False      False
# ...       ...     ...            ...        ...          ...        ...
# 138146  False   False          False      False        False      False
# 138147  False   False          False      False        False      False
# 138148  False   False          False      False        False      False
# 138149  False   False          False      False        False      False
# 138150  False   False          False      False        False      False
#
#         EndDate  Gender   Date  Medium  Dimensions  CreditLine  \
# ...

# %%
moma_df.isna().sum()
# Out:
# Title                     39
# Artist                  1283
# ConstituentID           1283
# ArtistBio               5925
# Nationality             6308
# BeginDate               1283
# EndDate                47354
# Gender                  8641
# Date                    2202
# Medium                  9701
# Dimensions              9754
# CreditLine              2437
# AccessionNumber            0
# Classification             0
# Department                 0
# DateAcquired            7125
# Cataloged                  0
# ObjectID                   0
# URL                    50967
# ThumbnailURL           61742
# Circumference (cm)    138141
# Depth (cm)            124312
# Diameter (cm)         136689
# Height (cm)            17796
# Length (cm)           137409
# Weight (kg)           137861
# Width (cm)             18717
# Seat Height (cm)      138151
# Duration (sec.)       136011
# dtype: int64

# %%
moma_df.notna().sum()
# Out:
# Title                 138112
# Artist                136868
# ConstituentID         136868
# ArtistBio             132226
# Nationality           131843
# BeginDate             136868
# EndDate                90797
# Gender                129510
# Date                  135949
# Medium                128450
# Dimensions            128397
# CreditLine            135714
# AccessionNumber       138151
# Classification        138151
# Department            138151
# DateAcquired          131026
# Cataloged             138151
# ObjectID              138151
# URL                    87184
# ThumbnailURL           76409
# Circumference (cm)        10
# Depth (cm)             13839
# Diameter (cm)           1462
# Height (cm)           120355
# Length (cm)              742
# Weight (kg)              290
# Width (cm)            119434
# Seat Height (cm)           0
# Duration (sec.)         2140
# dtype: int64

# %%
moma_df.drop(['Seat Height (cm)'], axis= 1, inplace= True)

# %%
moma_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138151 entries, 0 to 138150
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Title               138112 non-null  object
#  1   Artist              136868 non-null  object
#  2   ConstituentID       136868 non-null  object
#  3   ArtistBio           132226 non-null  object
#  4   Nationality         131843 non-null  object
#  5   BeginDate           136868 non-null  object
#  6   EndDate             90797 non-null   object
#  7   Gender              129510 non-null  object
#  8   Date                135949 non-null  object
#  9   Medium              128450 non-null  object
#  10  Dimensions          128397 non-null  object
#  11  CreditLine          135714 non-null  object
#  12  AccessionNumber     138151 non-null  object
#  13  Classification      138151 non-null  object
#  14  Department          138151 non-null  object
# ...

# %%
# moma_df.fillna({'Depth': 0}, inplace= True)
moma_df['Depth (cm)'].fillna(value= 0, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# (Male)                                                                        104140
# (Female)                                                                       17821
# (Male) (Male)                                                                   1759
# (Male) (Male) (Male)                                                             876
# (Male) ()                                                                        817
#                                                                                ...
# (Female) (Female) (Female) ()                                                      1
# (Male) (Male) (Male) (Male) (Female) (Female) (Female) ()                          1
# (Male) (Male) (Male) (Male) (Male) (Male) (Male)                                   1
# (Female) (Male) (Female) (Male) (Male) () ()                                       1
# () (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)         1
# Name: Gender, Length: 408, dtype: int64

# %%
moma_df.Gender.str.count('(Female)').sum()
# Out:
# 21417.0

# %%
moma_df.Gender.str.count('(Male)').sum()
# Out:
# 119598.0

# %%
moma_df.Gender.str.count('(Male)').sum() + moma_df.Gender.str.count('(Female)').sum()
# Out:
# 141015.0

# %%
'''count males and female
if males > females - print M
if females > males - print F
if males == females - print U
else - print U'''


# for i in moma_df.Gender[:25]:
#     males = i.str.count('(Male)').sum()
#     females = i.str.count('(Female)').sum()
#     if males > females:
#         moma_df.replace(i, 'M', inplace= True)
# Out:
# 'count males and female\nif males > females - print M\nif females > males - print F\nif males == females - print U\nelse - print U'

# %%
moma_df.replace({'Gender': {np.nan : 'U'}}, inplace= True)

# %%
# moma_df.replace({'Gender': {'()' : ''}}, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# (Male)                                                                        104140
# (Female)                                                                       17821
# U                                                                               8641
# (Male) (Male)                                                                   1759
# (Male) (Male) (Male)                                                             876
#                                                                                ...
# (Female) (Female) (Female) ()                                                      1
# (Male) (Male) (Male) (Male) (Female) (Female) (Female) ()                          1
# (Male) (Male) (Male) (Male) (Male) (Male) (Male)                                   1
# (Female) (Male) (Female) (Male) (Male) () ()                                       1
# () (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male) (Male)         1
# Name: Gender, Length: 409, dtype: int64

# %%
male = 0
female = 0
for k,v in moma_df.Gender.iteritems():
    male = v.count('(Male)')
    female = v.count('(Female)')
    if male > female:
        moma_df.replace({'Gender': {v : 'M'}}, inplace= True)
    elif female > male:
        moma_df.replace({'Gender': {v : 'F'}}, inplace= True)
    elif male == female:
        moma_df.replace({'Gender': {v : 'U'}}, inplace= True)

# %%
moma_df.Gender.value_counts()
# Out:
# M                                                                                                        109634
# F                                                                                                         18171
# U                                                                                                          8641
# (Male) (Female)                                                                                             714
# (Female) (Male)                                                                                             484
# () ()                                                                                                       147
# () (Male) (Female)                                                                                          107
# (Male) (Female) ()                                                                                           56
# ...

# %%
moma_df.Gender.value_counts()

# %%
moma_df.loc[605]

# %%
# replace genders w/ M, F or U
# moma_df.replace({'Gender': {'(Male)': 'M', '(Female)': 'F', np.nan : 'U'}}, inplace= True)

# %%
moma_df.Gender.value_counts()

# %%
# moma_df.replace({'Gender': {'(Male) (Male)': 'M', 
#                             '(Male) (Male) (Male)': 'M', 
#                             '() (Male) (Male) (Male) (Male) () (Male) (Male) () (Male) () (Male) () (Male) () (Male) (Male) ()' : 'M'}}, 
#                 inplace= True)

# %%
# moma_df.replace({'Gender': {'(Male) ()': 'M',
#                             '(Male) (Male) (Female) (Male) (Male) (Male) (Male) (Male) (Male) (Female) ()': 'M', 
#                             '(Male) (Female)' : 'U'}}, inplace= True)

# %%
# moma_df.replace({'Gender': {'() (Male)': 'M',
#                             '() (Male) (Male) (Male) (Male) (Male) ()': 'M', 
#                             '(Female) (Male)' : 'U', 
#                             '() (Male) (Female) (Female) (Female) (Male) (Female) () (Male) (Male) (Female)' : 'F', 
#                             '(Male) (Male) (Female) (Female) (Female) (Male)' : 'U'}}, inplace= True)

# %%
# moma_df.replace({'Gender': {'(Female) (Female)': 'F',
#                             '() (Male) (Male) (Male) (Female) (Female) (Male) (Female) (Male) (Male) (Male) (Female) (Male) (Female) (Male) (Female) (Male) (Male) (Male) ': 'M', 
#                             '() ()' : 'U', 
#                             '(Male) (Male) (Male) (Female) (Female) (Male) (Male) (Female) (Male) (Male) (Male) ()' : 'M', 
#                             '(Male) (Male) (Male) ()' : 'M'}}, inplace= True)

# %%
moma_df.Gender.value_counts()

# %%
# moma_df.Gender.str.count('(Female)').sum()
